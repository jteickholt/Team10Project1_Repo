# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3041-72E3
#
#  Directory of C:\Users\StevenJBark\Desktop\RICEDAV\Projects\RiceBootcampProject1\Team10Project1_Repo\rawdata
#
# 11/14/2019  08:59 PM    <DIR>          .
# 11/14/2019  08:59 PM    <DIR>          ..
# 11/14/2019  07:56 PM                 1 .gitkeep
# 11/14/2019  08:02 PM    <DIR>          .ipynb_checkpoints
# 11/14/2019  08:53 PM            12,910 Categories_of_Interest_FY19_g05_STAAR_Data.txt
# 11/14/2019  07:56 PM        26,639,647 cfy19e5.csv
# 11/14/2019  08:59 PM             1,788 FinalHeaders.csv
# 11/14/2019  07:56 PM           550,912 fy19_varlist_g05.csv
# 11/14/2019  08:59 PM            94,534 SchoolData_Focused.ipynb
# 11/14/2019  08:01 PM             4,521 Untitled.ipynb
#                7 File(s)     27,304,313 bytes
#                3 Dir(s)  441,360,277,504 bytes free

# %%
headers = pd.read_csv('FinalHeaders.csv', header=0)
headers.head(10)
# Out:
#        ColumnHeaders
# 0             CAMPUS
# 1              DNAME
# 2              CNAME
# 3              GRADE
# 4   m_all_unsatgl_nm
# 5  m_sexm_unsatgl_nm
# 6  m_sexf_unsatgl_nm
# 7  m_ethh_unsatgl_nm
# 8  m_ethi_unsatgl_nm
# 9  m_etha_unsatgl_nm

# %%
headerlist = []

for index, row in headers.iterrows():
    headerlist.append(row[0])

headerlist
# Out:
# ['CAMPUS',
#  'DNAME',
#  'CNAME',
#  'GRADE',
#  'm_all_unsatgl_nm',
#  'm_sexm_unsatgl_nm',
#  'm_sexf_unsatgl_nm',
#  'm_ethh_unsatgl_nm',
#  'm_ethi_unsatgl_nm',
#  'm_etha_unsatgl_nm',
#  'm_ethb_unsatgl_nm',
#  'm_ethp_unsatgl_nm',
#  'm_ethw_unsatgl_nm',
#  'm_ecoy_unsatgl_nm',
#  'm_econ_unsatgl_nm',
#  'm_eco1_unsatgl_nm',
#  'm_eco2_unsatgl_nm',
#  'm_eco9_unsatgl_nm',
#  'm_ti19_unsatgl_nm',
#  'm_migy_unsatgl_nm',
#  'm_mign_unsatgl_nm',
#  'm_spey_unsatgl_nm',
#  'm_spen_unsatgl_nm',
#  'm_gify_unsatgl_nm',
#  'm_gifn_unsatgl_nm',
#  'm_atry_unsatgl_nm',
#  'm_atrn_unsatgl_nm',
#  'm_all_approgl_nm',
#  'm_sexm_approgl_nm',
#  'm_sexf_approgl_nm',
#  'm_ethh_approgl_nm',
#  'm_ethi_approgl_nm',
#  'm_etha_approgl_nm',
#  'm_ethb_approgl_nm',
#  'm_ethp_approgl_nm',
#  'm_ethw_approgl_nm',
#  'm_ecoy_approgl_nm',
#  'm_econ_approgl_nm',
#  'm_eco1_approgl_nm',
#  'm_eco2_approgl_nm',
#  'm_eco9_approgl_nm',
#  'm_ti19_approgl_nm',
#  'm_migy_approgl_nm',
# ...

# %%
schooldata_df = pd.read_csv('cfy19e5.csv', header=0)
schooldata_df.head()
# Out:
#     CAMPUS  YEAR  REGION  DISTRICT          DNAME            CNAME  GRADE  \
# 0  1902103    19       7      1902     CAYUGA ISD     CAYUGA ELEM.      5
# 1  1903102    19       7      1903    ELKHART ISD  ELKHART INTERME      5
# 2  1904102    19       7      1904  FRANKSTON ISD  FRANKSTON ELEM.      5
# 3  1906102    19       7      1906     NECHES ISD     NECHES ELEM.      5
# 4  1907110    19       7      1907  PALESTINE ISD  STORY INTERMEDI      5
#
#    r_all_docs_n  r_all_abs_n  r_all_oth_n  ...  s_gifn_avg_cat4  \
# 0            48            0            0  ...              9.3
# 1            83            0            0  ...              9.3
# 2            60            0            1  ...              9.1
# 3            24            0            0  ...              8.9
# 4           243            0            0  ...              7.8
#
#    s_gifn_pct_cat4  s_gifv_avg_cat4  s_gifv_pct_cat4  s_atry_avg_cat4  \
# ...

# %%
cleanedschooldata = schooldata_df[headerlist]

# %%
cleanedschooldata
# Out:
#          CAMPUS            DNAME            CNAME  GRADE  m_all_unsatgl_nm  \
# 0       1902103       CAYUGA ISD     CAYUGA ELEM.      5               4.0
# 1       1903102      ELKHART ISD  ELKHART INTERME      5               3.0
# 2       1904102    FRANKSTON ISD  FRANKSTON ELEM.      5               7.0
# 3       1906102       NECHES ISD     NECHES ELEM.      5               1.0
# 4       1907110    PALESTINE ISD  STORY INTERMEDI      5              58.0
# 5       1908101     WESTWOOD ISD   WESTWOOD ELEM.      5              43.0
# 6       1909101       SLOCUM ISD   SLOCUM PRE-K -      5               3.0
# 7       2901104      ANDREWS ISD  UNDERWOOD ELEM.      5              97.0
# 8       3801103  PINEYWOODS COMM   SARAH STRINDEN      5               5.0
# 9       3902102       HUDSON ISD  W.H. BONNER ELE      5               7.0
# 10      3903120       LUFKIN ISD   ANDERSON ELEM.      5              14.0
# ...

# %%
cleanedschooldata.to_csv('CleanedSchoolData.csv', header=True, index=False)
