# %% [markdown]
# ## Making Selected Census Demographic .csv File
# Use Census Data Tables and Python Wrapper to make Demographic file that can be used for School Project analysis.
# Use analysis to demonstrate the cooraletion between school students performance and those selected demographic factors.

# %% [markdown]
# Import Dependencies

# %%
import pandas as pd
from census import Census #<-- Python wrapper for census API
import requests

# Census API Key
from my_census import api_key

# provide the api key and the year to establish a session
c = Census(api_key, year=2017)

# Set an option to allow up to 300 characters to print in each column
pd.set_option('max_colwidth', 300)

# %% [markdown]
# Gather all of the available tables for the 2013 to 2017 ACS5 data

# %%
# query for all tables
tables = c.acs5.tables()

# The tables variable contains a list of dicts, so we can convert directly to a dataframe
table_df = pd.DataFrame(tables)
print(f"Number of available tables: {len(table_df)}")
table_df.head()
# Out:
# Number of available tables: 1127
#                                                                                                                                                          description  \
# 0  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME
# 1                                                                                                                                 SEX BY AGE BY COGNITIVE DIFFICULTY
# 2                                                       POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY WORK EXPERIENCE OF HOUSEHOLDER AND SPOUSE
# 3                                                                                                                                SEX BY AGE BY AMBULATORY DIFFICULTY
# 4                                                                                       POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER
#
#      name                                                     variables
# 0  B17015  https://api.census.gov/data/2017/acs/acs5/groups/B17015.json
# 1  B18104  https://api.census.gov/data/2017/acs/acs5/groups/B18104.json
# 2  B17016  https://api.census.gov/data/2017/acs/acs5/groups/B17016.json
# 3  B18105  https://api.census.gov/data/2017/acs/acs5/groups/B18105.json
# 4  B17017  https://api.census.gov/data/2017/acs/acs5/groups/B17017.json

# %% [markdown]
# Use the provided URL to retrieve available variables that I am interested

# %%
# Determine which tables will be used in the analysis
table_id = 'B25095'

# Capture the variables URL from the table_df
url = table_df.loc[table_df['name']==table_id, 'variables'].values[0]

# Make the API call
response = requests.get(url).json()
print(response)

# convert the response to a DataFrame
variables = pd.DataFrame(response['variables']).transpose()

# showing the full view of the dataframe and chose the demographic table that will be used in the analysis
variables.head
# Out:
# {'variables': {'B25095_063MA': {'label': 'Annotation of Margin of Error!!Total!!$100 000 to $149 999!!50.0 percent or more', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_063EA': {'label': 'Annotation of Estimate!!Total!!$100 000 to $149 999!!50.0 percent or more', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_064EA': {'label': 'Annotation of Estimate!!Total!!$100 000 to $149 999!!Not computed', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_064MA': {'label': 'Annotation of Margin of Error!!Total!!$100 000 to $149 999!!Not computed', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_061MA': {'label': 'Annotation of Margin of Error!!Total!!$100 000 to $149 999!!35.0 to 39.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_061EA': {'label': 'Annotation of Estimate!!Total!!$100 000 to $149 999!!35.0 to 39.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_062MA': {'label': 'Annotation of Margin of Error!!Total!!$100 000 to $149 999!!40.0 to 49.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_062EA': {'label': 'Annotation of Estimate!!Total!!$100 000 to $149 999!!40.0 to 49.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_068EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more!!25.0 to 29.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_067EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more!!20.0 to 24.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_067MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more!!20.0 to 24.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_069EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more!!30.0 to 34.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_068MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more!!25.0 to 29.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_065EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_065MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_066EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more!!Less than 20.0 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_066MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more!!Less than 20.0 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_060MA': {'label': 'Annotation of Margin of Error!!Total!!$100 000 to $149 999!!30.0 to 34.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_060EA': {'label': 'Annotation of Estimate!!Total!!$100 000 to $149 999!!30.0 to 34.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_069MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more!!30.0 to 34.9 percent', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_072MA': {'label': 'Annotation of Margin of Error!!Total!!$150 000 or more!!50.0 percent or more', 'predicateType': 'string', 'group': 'B25095', 'limit': 0, 'predicateOnly': True}, 'B25095_072EA': {'label': 'Annotation of Estimate!!Total!!$150 000 or more!!50.0 percent or more', 'predicateType': 'string ...
# Number of available variables: 292
# <bound method NDFrame.head of              concept   group  \
# B25095_063MA     NaN  B25095
# B25095_063EA     NaN  B25095
# B25095_064EA     NaN  B25095
# B25095_064MA     NaN  B25095
# B25095_061MA     NaN  B25095
# B25095_061EA     NaN  B25095
# B25095_062MA     NaN  B25095
# B25095_062EA     NaN  B25095
# B25095_068EA     NaN  B25095
# B25095_067EA     NaN  B25095
# B25095_067MA     NaN  B25095
# B25095_069EA     NaN  B25095
# B25095_068MA     NaN  B25095
# B25095_065EA     NaN  B25095
# B25095_065MA     NaN  B25095
# B25095_066EA     NaN  B25095
# B25095_066MA     NaN  B25095
# B25095_060MA     NaN  B25095
# B25095_060EA     NaN  B25095
# B25095_069MA     NaN  B25095
# B25095_072MA     NaN  B25095
# B25095_072EA     NaN  B25095
# B25095_073MA     NaN  B25095
# B25095_073EA     NaN  B25095
# B25095_070EA     NaN  B25095
# B25095_070MA     NaN  B25095
# B25095_071EA     NaN  B25095
# B25095_071MA     NaN  B25095
# B25095_002EA     NaN  B25095
# B25095_001MA     NaN  B25095
# ...              ...     ...
# B25095_043EA     NaN  B25095
# B25095_043MA     NaN  B25095
# B25095_045EA     NaN  B25095
# B25095_044EA     NaN  B25095
# B25095_044MA     NaN  B25095
# B25095_048EA     NaN  B25095
# B25095_047MA     NaN  B25095
# B25095_049EA     NaN  B25095
# B25095_049MA     NaN  B25095
# B25095_048MA     NaN  B25095
# B25095_050MA     NaN  B25095
# B25095_050EA     NaN  B25095
# B25095_051MA     NaN  B25095
# B25095_051EA     NaN  B25095
# B25095_054EA     NaN  B25095
# B25095_054MA     NaN  B25095
# B25095_055EA     NaN  B25095
# B25095_055MA     NaN  B25095
# B25095_052MA     NaN  B25095
# B25095_052EA     NaN  B25095
# B25095_053EA     NaN  B25095
# B25095_053MA     NaN  B25095
# B25095_059EA     NaN  B25095
# B25095_058MA     NaN  B25095
# B25095_059MA     NaN  B25095
# B25095_057EA     NaN  B25095
# B25095_056EA     NaN  B25095
# B25095_056MA     NaN  B25095
# B25095_058EA     NaN  B25095
# B25095_057MA     NaN  B25095
#
#                                                                                            label  \
# B25095_063MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!50.0 percent or more
# B25095_063EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!50.0 percent or more
# B25095_064EA                   Annotation of Estimate!!Total!!$100 000 to $149 999!!Not computed
# B25095_064MA            Annotation of Margin of Error!!Total!!$100 000 to $149 999!!Not computed
# B25095_061MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!35.0 to 39.9 percent
# B25095_061EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!35.0 to 39.9 percent
# B25095_062MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!40.0 to 49.9 percent
# B25095_062EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!40.0 to 49.9 percent
# B25095_068EA               Annotation of Estimate!!Total!!$150 000 or more!!25.0 to 29.9 percent
# B25095_067EA               Annotation of Estimate!!Total!!$150 000 or more!!20.0 to 24.9 percent
# B25095_067MA        Annotation of Margin of Error!!Total!!$150 000 or more!!20.0 to 24.9 percent
# B25095_069EA               Annotation of Estimate!!Total!!$150 000 or more!!30.0 to 34.9 percent
# B25095_068MA        Annotation of Margin of Error!!Total!!$150 000 or more!!25.0 to 29.9 percent
# B25095_065EA                                     Annotation of Estimate!!Total!!$150 000 or more
# B25095_065MA                              Annotation of Margin of Error!!Total!!$150 000 or more
# B25095_066EA             Annotation of Estimate!!Total!!$150 000 or more!!Less than 20.0 percent
# B25095_066MA      Annotation of Margin of Error!!Total!!$150 000 or more!!Less than 20.0 percent
# B25095_060MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!30.0 to 34.9 percent
# B25095_060EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!30.0 to 34.9 percent
# B25095_069MA        Annotation of Margin of Error!!Total!!$150 000 or more!!30.0 to 34.9 percent
# B25095_072MA        Annotation of Margin of Error!!Total!!$150 000 or more!!50.0 percent or more
# B25095_072EA               Annotation of Estimate!!Total!!$150 000 or more!!50.0 percent or more
# B25095_073MA                Annotation of Margin of Error!!Total!!$150 000 or more!!Not computed
# B25095_073EA                       Annotation of Estimate!!Total!!$150 000 or more!!Not computed
# B25095_070EA               Annotation of Estimate!!Total!!$150 000 or more!!35.0 to 39.9 percent
# B25095_070MA        Annotation of Margin of Error!!Total!!$150 000 or more!!35.0 to 39.9 percent
# B25095_071EA               Annotation of Estimate!!Total!!$150 000 or more!!40.0 to 49.9 percent
# B25095_071MA        Annotation of Margin of Error!!Total!!$150 000 or more!!40.0 to 49.9 percent
# B25095_002EA                                    Annotation of Estimate!!Total!!Less than $10 000
# B25095_001MA                                                Annotation of Margin of Error!!Total
# ...                                                                                          ...
# B25095_043EA             Annotation of Estimate!!Total!!$50 000 to $74 999!!35.0 to 39.9 percent
# B25095_043MA      Annotation of Margin of Error!!Total!!$50 000 to $74 999!!35.0 to 39.9 percent
# B25095_045EA             Annotation of Estimate!!Total!!$50 000 to $74 999!!50.0 percent or more
# B25095_044EA             Annotation of Estimate!!Total!!$50 000 to $74 999!!40.0 to 49.9 percent
# B25095_044MA      Annotation of Margin of Error!!Total!!$50 000 to $74 999!!40.0 to 49.9 percent
# B25095_048EA           Annotation of Estimate!!Total!!$75 000 to $99 999!!Less than 20.0 percent
# B25095_047MA                            Annotation of Margin of Error!!Total!!$75 000 to $99 999
# B25095_049EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!20.0 to 24.9 percent
# B25095_049MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!20.0 to 24.9 percent
# B25095_048MA    Annotation of Margin of Error!!Total!!$75 000 to $99 999!!Less than 20.0 percent
# B25095_050MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!25.0 to 29.9 percent
# B25095_050EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!25.0 to 29.9 percent
# B25095_051MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!30.0 to 34.9 percent
# B25095_051EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!30.0 to 34.9 percent
# B25095_054EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!50.0 percent or more
# B25095_054MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!50.0 percent or more
# B25095_055EA                     Annotation of Estimate!!Total!!$75 000 to $99 999!!Not computed
# B25095_055MA              Annotation of Margin of Error!!Total!!$75 000 to $99 999!!Not computed
# B25095_052MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!35.0 to 39.9 percent
# B25095_052EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!35.0 to 39.9 percent
# B25095_053EA             Annotation of Estimate!!Total!!$75 000 to $99 999!!40.0 to 49.9 percent
# B25095_053MA      Annotation of Margin of Error!!Total!!$75 000 to $99 999!!40.0 to 49.9 percent
# B25095_059EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!25.0 to 29.9 percent
# B25095_058MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!20.0 to 24.9 percent
# B25095_059MA    Annotation of Margin of Error!!Total!!$100 000 to $149 999!!25.0 to 29.9 percent
# B25095_057EA         Annotation of Estimate!!Total!!$100 000 to $149 999!!Less than 20.0 percent
# B25095_056EA                                 Annotation of Estimate!!Total!!$100 000 to $149 999
# B25095_056MA                          Annotation of Margin of Error!!Total!!$100 000 to $149 999
# B25095_058EA           Annotation of Estimate!!Total!!$100 000 to $149 999!!20.0 to 24.9 percent
# B25095_057MA  Annotation of Margin of Error!!Total!!$100 000 to $149 999!!Less than 20.0 percent
#
#              limit predicateOnly predicateType
# B25095_063MA     0          True        string
# B25095_063EA     0          True        string
# B25095_064EA     0          True        string
# B25095_064MA     0          True        string
# B25095_061MA     0          True        string
# B25095_061EA     0          True        string
# B25095_062MA     0          True        string
# B25095_062EA     0          True        string
# B25095_068EA     0          True        string
# B25095_067EA     0          True        string
# B25095_067MA     0          True        string
# B25095_069EA     0          True        string
# B25095_068MA     0          True        string
# B25095_065EA     0          True        string
# B25095_065MA     0          True        string
# B25095_066EA     0          True        string
# B25095_066MA     0          True        string
# B25095_060MA     0          True        string
# B25095_060EA     0          True        string
# B25095_069MA     0          True        string
# B25095_072MA     0          True        string
# B25095_072EA     0          True        string
# B25095_073MA     0          True        string
# B25095_073EA     0          True        string
# B25095_070EA     0          True        string
# B25095_070MA     0          True        string
# B25095_071EA     0          True        string
# B25095_071MA     0          True        string
# B25095_002EA     0          True        string
# B25095_001MA     0          True        string
# ...            ...           ...           ...
# B25095_043EA     0          True        string
# B25095_043MA     0          True        string
# B25095_045EA     0          True        string
# B25095_044EA     0          True        string
# B25095_044MA     0          True        string
# B25095_048EA     0          True        string
# B25095_047MA     0          True        string
# B25095_049EA     0          True        string
# B25095_049MA     0          True        string
# B25095_048MA     0          True        string
# B25095_050MA     0          True        string
# B25095_050EA     0          True        string
# B25095_051MA     0          True        string
# B25095_051EA     0          True        string
# B25095_054EA     0          True        string
# B25095_054MA     0          True        string
# B25095_055EA     0          True        string
# B25095_055MA     0          True        string
# B25095_052MA     0          True        string
# B25095_052EA     0          True        string
# B25095_053EA     0          True        string
# B25095_053MA     0          True        string
# B25095_059EA     0          True        string
# B25095_058MA     0          True        string
# B25095_059MA     0          True        string
# B25095_057EA     0          True        string
# B25095_056EA     0          True        string
# B25095_056MA     0          True        string
# B25095_058EA     0          True        string
# B25095_057MA     0          True        string
#
# [292 rows x 6 columns]>

# %%
# Filter to only fields that will contain an integer
variables[variables['predicateType']=='int'].head()
# Out:
#                                                                                                                 concept  \
# B25095_032M  HOUSEHOLD INCOME BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS
# B25095_032E  HOUSEHOLD INCOME BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS
# B25095_031M  HOUSEHOLD INCOME BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS
# B25095_031E  HOUSEHOLD INCOME BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS
# B25095_034M  HOUSEHOLD INCOME BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS
#
#               group  \
# B25095_032M  B25095
# B25095_032E  B25095
# B25095_031M  B25095
# B25095_031E  B25095
# B25095_034M  B25095
#
#                                                                         label  \
# B25095_032M  Margin of Error!!Total!!$35 000 to $49 999!!25.0 to 29.9 percent
# B25095_032E         Estimate!!Total!!$35 000 to $49 999!!25.0 to 29.9 percent
# B25095_031M  Margin of Error!!Total!!$35 000 to $49 999!!20.0 to 24.9 percent
# B25095_031E         Estimate!!Total!!$35 000 to $49 999!!20.0 to 24.9 percent
# B25095_034M  Margin of Error!!Total!!$35 000 to $49 999!!35.0 to 39.9 percent
#
#             limit predicateOnly predicateType
# B25095_032M     0          True           int
# B25095_032E     0          True           int
# B25095_031M     0          True           int
# B25095_031E     0          True           int
# B25095_034M     0          True           int

# %% [markdown]
# Use the wrapper to query for selected fields. In this code, I want data for these 6 fields for ALL zip codes.

# %%
census_data = c.acs5.get(("B25095_063E", "B25095_045E","B15003_023E", "B15003_017E", "B17006_006E", "B17006_020E"), 
                         {'for': 'zip code tabulation area:*'})

census_data[:5]
len(census_data)
# Out:
# 33120

# %% [markdown]
# Format the response

# %%
# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Renaming columns to be more user-friendly
census_pd = census_pd.rename(columns={"B25095_063E": "Income Over 100K",
                                      "B25095_045E": "Income Below 75K",
                                      "B15003_023E": "Master Degree",
                                      "B15003_017E": "High School Diploma",
                                      "B17006_006E": "Poverty Family",
                                      "B17006_020E": "Non Poverty Family", 
                                      "zip code tabulation area": "Zipcode"})

# Reorder columns for the final DataFrame
census_pd = census_pd[["Zipcode", "Income Below 75K", "Income Over 100K", "High School Diploma",
                       "Master Degree", "Poverty Family", "Non Poverty Family"]]

# Visualize
print("Total number of zip codes in response: " + str(len(census_pd)))
census_pd.head()
# Out:
# Total number of zip codes in response: 33120
#   Zipcode  Income Below 75K  Income Over 100K  High School Diploma  \
# 0   84306               0.0               0.0                 24.0
# 1   84775               0.0               0.0                 50.0
# 2   84762               0.0               0.0                 83.0
# 3   84772               0.0               0.0                 61.0
# 4   84781               0.0               0.0                 23.0
#
#    Master Degree  Poverty Family  Non Poverty Family
# 0           18.0             0.0                40.0
# 1           58.0             0.0                16.0
# 2           22.0             0.0                 0.0
# 3            8.0             0.0                32.0
# 4            0.0             0.0                38.0

# %% [markdown]
# ###### Save to a CSV

# %%
census_pd.to_csv("census_demo.csv", encoding="utf-8", index=False)
