# %%
#Calculations dataframes for analysis of STAAR data.
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
#Import cleaned STAAR data for Grade 3, all students.
grade3all_df = pd.read_csv('../cleandata/AllStudentsGrade3.csv', header=0)
grade3all_df.head()
# Out:
#     CAMPUS          DNAME            CNAME  GRADE District Type  \
# 0  1902103     CAYUGA ISD     CAYUGA ELEM.      3   INDEPENDENT
# 1  1903102    ELKHART ISD  ELKHART INTERME      3   INDEPENDENT
# 2  1904102  FRANKSTON ISD  FRANKSTON ELEM.      3   INDEPENDENT
# 3  1906102     NECHES ISD     NECHES ELEM.      3   INDEPENDENT
# 4  1907107  PALESTINE ISD  SOUTHSIDE ELEM.      3   INDEPENDENT
#
#   School Street Address School City  School Zip  Below Grade Level  \
# 0           P O BOX 427      CAYUGA  75832-0427                6.0
# 1       301 E PARKER ST     ELKHART  75839-9701               26.0
# 2           P O BOX 428   FRANKSTON  75763-0428               16.0
# 3           P O BOX 310      NECHES  75779-0310                5.0
# 4      201 GILLESPIE RD   PALESTINE  75801-7627               46.0
#
#    Approach Grade Level  Meet Grade Level  Master Grade Level
# 0                  40.0              38.0                27.0
# 1                  68.0              37.0                12.0
# 2                  39.0              26.0                10.0
# 3                  20.0               7.0                 2.0
# 4                 174.0              93.0                51.0

# %%
#Set up a dataframe for calculating all of the means for each school. This can't be done directly because the scoring
#for STAAR tests is on a string-type Below, Approach, Meet, and Master. I assigned grading to these strings as
#Below = 1, Approach = 2, Meet = 3, Master = 4. Mean = #Students*Score for each category divided by #Students Total. 
grade3mean_df = grade3all_df[['CNAME', 
                              'District Type',
                              'Below Grade Level',
                              'Approach Grade Level',
                              'Meet Grade Level',
                              'Master Grade Level']]

grade3mean_df.head()
# Out:
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                6.0                  40.0
# 1  ELKHART INTERME   INDEPENDENT               26.0                  68.0
# 2  FRANKSTON ELEM.   INDEPENDENT               16.0                  39.0
# 3     NECHES ELEM.   INDEPENDENT                5.0                  20.0
# 4  SOUTHSIDE ELEM.   INDEPENDENT               46.0                 174.0
#
#    Meet Grade Level  Master Grade Level
# 0              38.0                27.0
# 1              37.0                12.0
# 2              26.0                10.0
# 3               7.0                 2.0
# 4              93.0                51.0

# %%
#Make total column for mean calculation
grade3mean_df['total'] = grade3mean_df.sum(axis=1)
grade3mean_df.head()
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                6.0                  40.0
# 1  ELKHART INTERME   INDEPENDENT               26.0                  68.0
# 2  FRANKSTON ELEM.   INDEPENDENT               16.0                  39.0
# 3     NECHES ELEM.   INDEPENDENT                5.0                  20.0
# 4  SOUTHSIDE ELEM.   INDEPENDENT               46.0                 174.0
#
#    Meet Grade Level  Master Grade Level  total
# 0              38.0                27.0  111.0
# 1              37.0                12.0  143.0
# 2              26.0                10.0   91.0
# 3               7.0                 2.0   34.0
# 4              93.0                51.0  364.0

# %%
#Calculate mean and make new column
grade3mean_df['mean'] = (grade3mean_df['Below Grade Level']*1 +
                         grade3mean_df['Approach Grade Level']*2 +
                         grade3mean_df['Meet Grade Level']*3 +
                         grade3mean_df['Master Grade Level']*4) / grade3mean_df['total']

grade3mean_df
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                 CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0        CAYUGA ELEM.   INDEPENDENT                6.0                  40.0
# 1     ELKHART INTERME   INDEPENDENT               26.0                  68.0
# 2     FRANKSTON ELEM.   INDEPENDENT               16.0                  39.0
# 3        NECHES ELEM.   INDEPENDENT                5.0                  20.0
# 4     SOUTHSIDE ELEM.   INDEPENDENT               46.0                 174.0
# 5      WESTWOOD ELEM.   INDEPENDENT               50.0                  56.0
# 6      SLOCUM PRE-K -   INDEPENDENT                5.0                  22.0
# 7      DEVONIAN ELEM.   INDEPENDENT               49.0                 232.0
# 8      SARAH STRINDEN       CHARTER               15.0                  65.0
# 9     W.H. BONNER ELE   INDEPENDENT               27.0                 166.0
# 10     ANDERSON ELEM.   INDEPENDENT               29.0                  50.0
# 11      BRANDON ELEM.   INDEPENDENT               29.0                  96.0
# 12    BROOKHOLLOW ELE   INDEPENDENT               37.0                  64.0
# 13       COSTON ELEM.   INDEPENDENT               23.0                  55.0
# 14        SLACK ELEM.   INDEPENDENT               29.0                 127.0
# 15    HUNTINGTON ELEM   INDEPENDENT               27.0                  86.0
# 16    H.G. TEMPLE INT   INDEPENDENT               31.0                  76.0
# 17      ZAVALLA ELEM.   INDEPENDENT                4.0                  23.0
# 18      CENTRAL ELEM.   INDEPENDENT               28.0                  74.0
# 19    FULTON LEARNING   INDEPENDENT               91.0                 126.0
# 20    ARCHER CITY ELE   INDEPENDENT                0.0                  27.0
# 21     HOLLIDAY ELEM.   INDEPENDENT               15.0                  53.0
# 22    WINDTHORST ELEM   INDEPENDENT                1.0                  22.0
# 23       CLAUDE ELEM.           NaN                3.0                  24.0
# 24    CHARLOTTE ELEM.   INDEPENDENT                2.0                  28.0
# 25    JOURDANTON ELEM   INDEPENDENT               35.0                  84.0
# 26        LYTLE ELEM.   INDEPENDENT               45.0                  74.0
# 27    PLEASANTON ELEM   INDEPENDENT               79.0                 159.0
# 28       POTEET ELEM.   INDEPENDENT               41.0                  90.0
# 29    O'BRYANT PRIMAR   INDEPENDENT               30.0                 113.0
# ...               ...           ...                ...                   ...
# 4537       POTH ELEM.   INDEPENDENT                9.0                  37.0
# 4538  STOCKDALE ELEM.   INDEPENDENT                9.0                  34.0
# 4539     KERMIT ELEM.   INDEPENDENT               41.0                  61.0
# 4540       WINK ELEM.   INDEPENDENT               10.0                  21.0
# 4541     ALVORD ELEM.   INDEPENDENT                5.0                  47.0
# 4542       BOYD ELEM.   INDEPENDENT               21.0                  68.0
# 4543  BRIDGEPORT INTE   INDEPENDENT               37.0                 103.0
# 4544      CHICO ELEM.   INDEPENDENT               18.0                  31.0
# 4545       RANN ELEM.   INDEPENDENT               25.0                  66.0
# 4546     CARSON ELEM.   INDEPENDENT               17.0                  64.0
# 4547      YOUNG ELEM.   INDEPENDENT               21.0                  51.0
# 4548   PARADISE ELEM.   INDEPENDENT                6.0                  79.0
# 4549  SLIDELL SCHOOLS   INDEPENDENT                5.0                  12.0
# 4550    HAWKINS ELEM.   INDEPENDENT               11.0                  42.0
# 4551    MINEOLA ELEM.   INDEPENDENT               44.0                  84.0
# 4552    QUITMAN ELEM.   INDEPENDENT               10.0                  67.0
# 4553     YANTIS ELEM.   INDEPENDENT                3.0                  25.0
# 4556              43.0                23.0  191.0  2.240838
# 4557              11.0                 1.0   44.0  1.977273
# 4558              65.0                32.0  263.0  2.326996
# 4559               5.0                 2.0   21.0  2.285714
# 4560              19.0                 5.0   76.0  2.184211
# 4561               4.0                 2.0   18.0  2.333333
# 4562              54.0                30.0  168.0  2.613095
# 4563              44.0                21.0  145.0  2.468966
# 4564              37.0                17.0  132.0  2.439394
# 4565              36.0                17.0  192.0  2.130208
# 4566              12.0                 5.0   54.0  2.259259
#
# [4567 rows x 8 columns]

# %%
#Boxplot uses vectors or arrays. I need to generate arrays of the means for Charter and Independent schools.
#Most simple from the grade3mean_df data.

#PROBLEM! Null values in several rows of the data. CHECKED STATUS OF THESE ROWS:
#independent.loc[independent.isnull().any(axis=1)]
#charter.loc[charter.isnull().any(axis=1)]
#IN ALL CASES THESE ROWS WERE COMPLETELY EMPHTY AND WERE DELETED!

independent3 = grade3mean_df.loc[grade3mean_df['District Type'] == 'INDEPENDENT']
independent3.loc[independent3.isnull().any(axis=1)]

charter3 = grade3mean_df.loc[grade3mean_df['District Type'] == 'CHARTER']
charter3.loc[charter3.isnull().any(axis=1)]
# Out:
#                 CNAME District Type  Below Grade Level  Approach Grade Level  \
# 861   AZLEWAY - WILLO       CHARTER                NaN                   NaN
# 954   NOVA ACAD. CEDA       CHARTER                NaN                   NaN
# 1570  LA FE PREPARATO       CHARTER                NaN                   NaN
# 1998   PHOENIX SCHOOL       CHARTER                NaN                   NaN
# 4106  GEORGE M. KOZME       CHARTER                NaN                   NaN
# 4107  TNC CAMPUS (TEX       CHARTER                NaN                   NaN
# 4108  DEPELCHIN-RICHM       CHARTER                NaN                   NaN
# 4109     LAUREL RIDGE       CHARTER                NaN                   NaN
# 4110    OLYMPIA HILLS       CHARTER                NaN                   NaN
# 4112  UT - UNIVERSITY       CHARTER                NaN                   NaN
# 4113  SHRINERS HOSPIT       CHARTER                NaN                   NaN
#
#       Meet Grade Level  Master Grade Level  total  mean
# 861                NaN                 NaN    0.0   NaN
# 954                NaN                 NaN    0.0   NaN
# 1570               NaN                 NaN    0.0   NaN
# 1998               NaN                 NaN    0.0   NaN
# 4106               NaN                 NaN    0.0   NaN
# 4107               NaN                 NaN    0.0   NaN
# 4108               NaN                 NaN    0.0   NaN
# 4109               NaN                 NaN    0.0   NaN
# 4110               NaN                 NaN    0.0   NaN
# 4112               NaN                 NaN    0.0   NaN
# 4113               NaN                 NaN    0.0   NaN

# %%
#Delete empty rows from the independent and charter dataframes. Check using isnull().any() to confirm.
independent3 = independent3.dropna(how='any')
independent3.isnull().any()

charter3 = charter3.dropna(how='any')
charter3.isnull().any()
# Out:
# CNAME                   False
# District Type           False
# Below Grade Level       False
# Approach Grade Level    False
# Meet Grade Level        False
# Master Grade Level      False
# total                   False
# mean                    False
# dtype: bool

# %%
#Instead of calculating statistics individually, use the .describe() function.
stats3mean_ind_df = independent3['mean'].describe()
stats3mean_ind_df
# Out:
# count    4152.000000
# mean        2.375701
# std         0.248425
# min         1.250000
# 25%         2.225679
# 50%         2.395535
# 75%         2.555556
# max         3.000000
# Name: mean, dtype: float64

# %%
stats3mean_cht_df = charter3['mean'].describe()
stats3mean_cht_df
# Out:
# count    351.000000
# mean       2.262779
# std        0.344194
# min        1.000000
# 25%        2.086031
# 50%        2.295775
# 75%        2.506209
# max        2.871795
# Name: mean, dtype: float64

# %%
#Create vectors for independent and charter school means. Use independent2 and charter2 dataframes where null values were
#removed.
I_vector3 = []
for index, row in independent3.iterrows():
    I_vector3.append(row[7])

C_vector3 = []
for index, row in charter3.iterrows():
    C_vector3.append(row[7])

# %%
#Check the I_vector and C_vector (These are actually just the vectors of the means for Independent and Charter schools)
[len(I_vector3), len(C_vector3)]
# Out:
# [4152, 351]

# %%
#Check Student's T test
from scipy import stats
(t, statp) = sp.stats.ttest_ind(I_vector3, C_vector3, equal_var=True)
statp3 = statp
statp3
# Out:
# 3.484022814201602e-15

# %%
#Boxplot using the I_vector and C_vector generated above.
boxplot_data = [I_vector3, C_vector3]
labels = ['Independent', 'Charter']

plt.figure(figsize=(9,6))
plt.boxplot(boxplot_data)

plt.ylim(0.5, 3.5)

plt.suptitle('Independent versus Charter School Means', ha='center', fontsize=16, fontweight='bold')
plt.title('2019 STAAR Test, Mathematics, Grade 3', ha='center', fontsize=16, fontweight='bold')
plt.xlabel('School Type', fontsize=14, fontweight='bold')
plt.ylabel('Mean Score', fontsize=14, fontweight='bold')
plt.xticks([1,2],['Independent (N=4152, Mean=2.376)', 'Charter (N=351, Mean=2.263)'], fontsize=12)
plt.text(0.6,0.6,f'P-Value={statp3}')

#Save figure
plt.savefig('../reports/BoxAllStudentsGrade3', dpi=300)

# %%
#Import cleaned STAAR data for Grade 4, all students.
grade4all_df = pd.read_csv('../cleandata/AllStudentsGrade4.csv', header=0)
grade4all_df.head()
# Out:
#     CAMPUS          DNAME            CNAME  GRADE District Type  \
# 0  1902103     CAYUGA ISD     CAYUGA ELEM.      4   INDEPENDENT
# 1  1903102    ELKHART ISD  ELKHART INTERME      4   INDEPENDENT
# 2  1904102  FRANKSTON ISD  FRANKSTON ELEM.      4   INDEPENDENT
# 3  1906102     NECHES ISD     NECHES ELEM.      4   INDEPENDENT
# 4  1907110  PALESTINE ISD  STORY INTERMEDI      4   INDEPENDENT
#
#   School Street Address School City  School Zip  Below Grade Level  \
# 0           P O BOX 427      CAYUGA  75832-0427                6.0
# 1       301 E PARKER ST     ELKHART  75839-9701                4.0
# 2           P O BOX 428   FRANKSTON  75763-0428               26.0
# 3           P O BOX 310      NECHES  75779-0310                2.0
# 4       5300 S LOOP 256   PALESTINE  75801-2415              106.0
#
#    Approach Grade Level  Meet Grade Level  Master Grade Level
# 0                  44.0              27.0                13.0
# 1                  93.0              63.0                40.0
# 2                  52.0              25.0                15.0
# 3                  23.0               9.0                 2.0
# 4                 143.0              80.0                45.0

# %%
grade4mean_df = grade4all_df[['CNAME', 
                              'District Type',
                              'Below Grade Level',
                              'Approach Grade Level',
                              'Meet Grade Level',
                              'Master Grade Level']]

grade4mean_df.head()
# Out:
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                6.0                  44.0
# 1  ELKHART INTERME   INDEPENDENT                4.0                  93.0
# 2  FRANKSTON ELEM.   INDEPENDENT               26.0                  52.0
# 3     NECHES ELEM.   INDEPENDENT                2.0                  23.0
# 4  STORY INTERMEDI   INDEPENDENT              106.0                 143.0
#
#    Meet Grade Level  Master Grade Level
# 0              27.0                13.0
# 1              63.0                40.0
# 2              25.0                15.0
# 3               9.0                 2.0
# 4              80.0                45.0

# %%
grade4mean_df['total'] = grade4mean_df.sum(axis=1)
grade4mean_df.head()
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                6.0                  44.0
# 1  ELKHART INTERME   INDEPENDENT                4.0                  93.0
# 2  FRANKSTON ELEM.   INDEPENDENT               26.0                  52.0
# 3     NECHES ELEM.   INDEPENDENT                2.0                  23.0
# 4  STORY INTERMEDI   INDEPENDENT              106.0                 143.0
#
#    Meet Grade Level  Master Grade Level  total
# 0              27.0                13.0   90.0
# 1              63.0                40.0  200.0
# 2              25.0                15.0  118.0
# 3               9.0                 2.0   36.0
# 4              80.0                45.0  374.0

# %%
grade4mean_df['mean'] = (grade4mean_df['Below Grade Level']*1 +
                         grade4mean_df['Approach Grade Level']*2 +
                         grade4mean_df['Meet Grade Level']*3 +
                         grade4mean_df['Master Grade Level']*4) / grade4mean_df['total']

grade4mean_df
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                 CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0        CAYUGA ELEM.   INDEPENDENT                6.0                  44.0
# 1     ELKHART INTERME   INDEPENDENT                4.0                  93.0
# 2     FRANKSTON ELEM.   INDEPENDENT               26.0                  52.0
# 3        NECHES ELEM.   INDEPENDENT                2.0                  23.0
# 4     STORY INTERMEDI   INDEPENDENT              106.0                 143.0
# 5      WESTWOOD ELEM.   INDEPENDENT               46.0                  72.0
# 6      SLOCUM PRE-K -   INDEPENDENT                6.0                  20.0
# 7     UNDERWOOD ELEM.   INDEPENDENT               93.0                 230.0
# 8      SARAH STRINDEN       CHARTER                7.0                  80.0
# 9     W.H. BONNER ELE   INDEPENDENT               47.0                 184.0
# 10     ANDERSON ELEM.   INDEPENDENT               17.0                  56.0
# 11      BRANDON ELEM.   INDEPENDENT               36.0                  92.0
# 12    BROOKHOLLOW ELE   INDEPENDENT               39.0                  42.0
# 13       COSTON ELEM.   INDEPENDENT               23.0                  51.0
# 14        SLACK ELEM.   INDEPENDENT               31.0                 128.0
# 15    HUNTINGTON INTE   INDEPENDENT               31.0                  72.0
# 16    H.G. TEMPLE INT   INDEPENDENT               50.0                  73.0
# 17      ZAVALLA ELEM.   INDEPENDENT                9.0                  19.0
# 18      CENTRAL ELEM.   INDEPENDENT               30.0                  82.0
# 19    FULTON LEARNING   INDEPENDENT               54.0                 142.0
# 20    ARCHER CITY ELE   INDEPENDENT                8.0                  28.0
# 21     HOLLIDAY ELEM.   INDEPENDENT               19.0                  63.0
# 22    WINDTHORST ELEM   INDEPENDENT                1.0                  25.0
# 23       CLAUDE ELEM.           NaN                8.0                  17.0
# 24    CHARLOTTE ELEM.   INDEPENDENT               14.0                  24.0
# 25    JOURDANTON ELEM   INDEPENDENT               26.0                  87.0
# 26        LYTLE ELEM.   INDEPENDENT               49.0                  88.0
# 27    PLEASANTON ELEM   INDEPENDENT              118.0                 167.0
# 28    POTEET INTERMED   INDEPENDENT               45.0                  79.0
# 29    O'BRYANT INTERM   INDEPENDENT               51.0                 100.0
# ...               ...           ...                ...                   ...
# 23                12.0                 3.0   40.0  2.250000
# 24                12.0                 8.0   58.0  2.241379
# 25                46.0                28.0  187.0  2.406417
# 26                45.0                17.0  199.0  2.150754
# 27                88.0                53.0  426.0  2.178404
# 28                43.0                23.0  190.0  2.231579
# 29                66.0                26.0  243.0  2.275720
# ...                ...                 ...    ...       ...
# 4526              39.0                22.0  129.0  2.542636
# 4527              28.0                13.0  103.0  2.446602
# 4528              26.0                11.0  149.0  2.020134
# 4529              18.0                11.0   62.0  2.564516
# 4530              33.0                20.0  103.0  2.650485
# 4531              38.0                20.0  149.0  2.348993
# 4532              53.0                25.0  229.0  2.227074
# 4533              32.0                23.0   93.0  2.827957
# 4534              38.0                11.0  149.0  2.208054
# 4535              29.0                13.0  123.0  2.243902
# 4536              29.0                 8.0  114.0  2.210526
# 4537              56.0                30.0  167.0  2.658683
# 4538              10.0                 6.0   37.0  2.405405
# 4539              29.0                21.0   97.0  2.690722
# 4540              48.0                25.0  214.0  2.219626
# 4541              38.0                24.0  142.0  2.521127
# 4542              11.0                 7.0   42.0  2.476190
# 4543              19.0                 8.0   92.0  2.076087
# 4544              39.0                20.0  168.0  2.279762
# 4545              37.0                18.0  174.0  2.235632
# 4546               7.0                 1.0   40.0  1.950000
# 4547              34.0                18.0  260.0  1.861538
# 4548               8.0                 5.0   28.0  2.535714
# 4549              18.0                 9.0   84.0  2.238095
# 4550               7.0                 1.0   24.0  2.375000
# 4551              36.0                15.0  139.0  2.302158
# 4552              30.0                11.0  132.0  2.128788
# 4553              22.0                 7.0  101.0  2.148515
# 4554              28.0                14.0  184.0  1.902174
# 4555              11.0                 6.0   57.0  2.192982
#
# [4556 rows x 8 columns]

# %%
independent4 = grade4mean_df.loc[grade4mean_df['District Type'] == 'INDEPENDENT']
independent4.loc[independent4.isnull().any(axis=1)]

charter4 = grade4mean_df.loc[grade4mean_df['District Type'] == 'CHARTER']
charter4.loc[charter4.isnull().any(axis=1)]
# Out:
#                 CNAME District Type  Below Grade Level  Approach Grade Level  \
# 126   JHW INSPIRE ACA       CHARTER                NaN                   NaN
# 128   JHW INSPIRE ACA       CHARTER                NaN                   NaN
# 860    PEGASUS SCHOOL       CHARTER                NaN                   NaN
# 861   AZLEWAY - WILLO       CHARTER                NaN                   NaN
# 1996   PHOENIX SCHOOL       CHARTER                NaN                   NaN
# 2001   COMQUEST ACAD.       CHARTER                NaN                   NaN
# 3017       OAKS ACAD.       CHARTER                NaN                   NaN
# 4098  GEORGE M. KOZME       CHARTER                NaN                   NaN
# 4099  TNC CAMPUS (TEX       CHARTER                NaN                   NaN
# 4100  DEPELCHIN-RICHM       CHARTER                NaN                   NaN
# 4101     LAUREL RIDGE       CHARTER                NaN                   NaN
# 4104  UT - UNIVERSITY       CHARTER                NaN                   NaN
#
#       Meet Grade Level  Master Grade Level  total  mean
# 126                NaN                 NaN    0.0   NaN
# 128                NaN                 NaN    0.0   NaN
# 860                NaN                 NaN    0.0   NaN
# 861                NaN                 NaN    0.0   NaN
# 1996               NaN                 NaN    0.0   NaN
# 2001               NaN                 NaN    0.0   NaN
# 3017               NaN                 NaN    0.0   NaN
# 4098               NaN                 NaN    0.0   NaN
# 4099               NaN                 NaN    0.0   NaN
# 4100               NaN                 NaN    0.0   NaN
# 4101               NaN                 NaN    0.0   NaN
# 4104               NaN                 NaN    0.0   NaN

# %%
independent4 = independent4.dropna(how='any')
independent4.isnull().any()

charter4 = charter4.dropna(how='any')
charter4.isnull().any()
# Out:
# CNAME                   False
# District Type           False
# Below Grade Level       False
# Approach Grade Level    False
# Meet Grade Level        False
# Master Grade Level      False
# total                   False
# mean                    False
# dtype: bool

# %%
stats4mean_ind_df = independent4['mean'].describe()
stats4mean_ind_df
# Out:
# count    4129.000000
# mean        2.368445
# std         0.278756
# min         1.000000
# 25%         2.204545
# 50%         2.397163
# 75%         2.562162
# max         3.000000
# Name: mean, dtype: float64

# %%
stats4mean_cht_df = charter4['mean'].describe()
stats4mean_cht_df
# Out:
# count    348.000000
# mean       2.230698
# std        0.362820
# min        1.000000
# 25%        2.043535
# 50%        2.269203
# 75%        2.500000
# max        2.889908
# Name: mean, dtype: float64

# %%
I_vector4 = []
for index, row in independent4.iterrows():
    I_vector4.append(row[7])

C_vector4 = []
for index, row in charter4.iterrows():
    C_vector4.append(row[7])

# %%
[len(I_vector4), len(C_vector4)]
# Out:
# [4129, 348]

# %%
(t, statp) = sp.stats.ttest_ind(I_vector4, C_vector4, equal_var=True)
statp4 = statp
statp4
# Out:
# 8.87363407689202e-18

# %%
#Boxplot using the I_vector and C_vector generated above.
boxplot_data = [I_vector4, C_vector4]
labels = ['Independent', 'Charter']

plt.figure(figsize=(9,6))
plt.boxplot(boxplot_data)

plt.ylim(0.5, 3.5)

plt.suptitle('Independent versus Charter School Means', ha='center', fontsize=16, fontweight='bold')
plt.title('2019 STAAR Test, Mathematics, Grade 4', ha='center', fontsize=16, fontweight='bold')
plt.xlabel('School Type', fontsize=14, fontweight='bold')
plt.ylabel('Mean Score', fontsize=14, fontweight='bold')
plt.xticks([1,2],['Independent (N=4129, Mean=2.368)', 'Charter (N=348, Mean=2.231)'], fontsize=12)
plt.text(0.6,0.6,f'P-Value={statp4}')

#Save figure
plt.savefig('../reports/BoxAllStudentsGrade4', dpi=300)

# %%
#Import cleaned STAAR data for Grade 5, all students.
grade5all_df = pd.read_csv('../cleandata/AllStudentsGrade5.csv', header=0)
grade5all_df.head()
# Out:
#     CAMPUS          DNAME            CNAME  GRADE District Type  \
# 0  1902103     CAYUGA ISD     CAYUGA ELEM.      5   INDEPENDENT
# 1  1903102    ELKHART ISD  ELKHART INTERME      5   INDEPENDENT
# 2  1904102  FRANKSTON ISD  FRANKSTON ELEM.      5   INDEPENDENT
# 3  1906102     NECHES ISD     NECHES ELEM.      5   INDEPENDENT
# 4  1907110  PALESTINE ISD  STORY INTERMEDI      5   INDEPENDENT
#
#   School Street Address School City  School Zip  Below Grade Level  \
# 0           P O BOX 427      CAYUGA  75832-0427                4.0
# 1       301 E PARKER ST     ELKHART  75839-9701                3.0
# 2           P O BOX 428   FRANKSTON  75763-0428                7.0
# 3           P O BOX 310      NECHES  75779-0310                1.0
# 4       5300 S LOOP 256   PALESTINE  75801-2415               58.0
#
#    Approach Grade Level  Meet Grade Level  Master Grade Level
# 0                  44.0              41.0                29.0
# 1                  80.0              65.0                43.0
# 2                  53.0              40.0                26.0
# 3                  23.0              15.0                10.0
# 4                 185.0             106.0                51.0

# %%
grade5mean_df = grade5all_df[['CNAME', 
                              'District Type',
                              'Below Grade Level',
                              'Approach Grade Level',
                              'Meet Grade Level',
                              'Master Grade Level']]

grade5mean_df.head()
# Out:
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                4.0                  44.0
# 1  ELKHART INTERME   INDEPENDENT                3.0                  80.0
# 2  FRANKSTON ELEM.   INDEPENDENT                7.0                  53.0
# 3     NECHES ELEM.   INDEPENDENT                1.0                  23.0
# 4  STORY INTERMEDI   INDEPENDENT               58.0                 185.0
#
#    Meet Grade Level  Master Grade Level
# 0              41.0                29.0
# 1              65.0                43.0
# 2              40.0                26.0
# 3              15.0                10.0
# 4             106.0                51.0

# %%
grade5mean_df['total'] = grade5mean_df.sum(axis=1)
grade5mean_df.head()
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0     CAYUGA ELEM.   INDEPENDENT                4.0                  44.0
# 1  ELKHART INTERME   INDEPENDENT                3.0                  80.0
# 2  FRANKSTON ELEM.   INDEPENDENT                7.0                  53.0
# 3     NECHES ELEM.   INDEPENDENT                1.0                  23.0
# 4  STORY INTERMEDI   INDEPENDENT               58.0                 185.0
#
#    Meet Grade Level  Master Grade Level  total
# 0              41.0                29.0  118.0
# 1              65.0                43.0  191.0
# 2              40.0                26.0  126.0
# 3              15.0                10.0   49.0
# 4             106.0                51.0  400.0

# %%
grade5mean_df['mean'] = (grade5mean_df['Below Grade Level']*1 +
                         grade5mean_df['Approach Grade Level']*2 +
                         grade5mean_df['Meet Grade Level']*3 +
                         grade5mean_df['Master Grade Level']*4) / grade5mean_df['total']

grade5mean_df
# Out:
# C:\Users\StevenJBark\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                 CNAME District Type  Below Grade Level  Approach Grade Level  \
# 0        CAYUGA ELEM.   INDEPENDENT                4.0                  44.0
# 1     ELKHART INTERME   INDEPENDENT                3.0                  80.0
# 2     FRANKSTON ELEM.   INDEPENDENT                7.0                  53.0
# 3        NECHES ELEM.   INDEPENDENT                1.0                  23.0
# 4     STORY INTERMEDI   INDEPENDENT               58.0                 185.0
# 5      WESTWOOD ELEM.   INDEPENDENT               43.0                  82.0
# 6      SLOCUM PRE-K -   INDEPENDENT                3.0                  20.0
# 7     UNDERWOOD ELEM.   INDEPENDENT               97.0                 220.0
# 8      SARAH STRINDEN       CHARTER                5.0                  77.0
# 9     W.H. BONNER ELE   INDEPENDENT                7.0                 203.0
# 10     ANDERSON ELEM.   INDEPENDENT               14.0                  71.0
# 11      BRANDON ELEM.   INDEPENDENT               35.0                  97.0
# 12    BROOKHOLLOW ELE   INDEPENDENT               23.0                  82.0
# 13       COSTON ELEM.   INDEPENDENT               12.0                  74.0
# 14        SLACK ELEM.   INDEPENDENT               44.0                 100.0
# 15    HUNTINGTON INTE   INDEPENDENT               12.0                 113.0
# 16    H.G. TEMPLE INT   INDEPENDENT               26.0                 117.0
# 17      ZAVALLA ELEM.   INDEPENDENT                3.0                  17.0
# 18      CENTRAL JR.H.   INDEPENDENT               24.0                  81.0
# 19    FULTON LEARNING   INDEPENDENT               71.0                 163.0
# 20    ARCHER CITY ELE   INDEPENDENT                1.0                  32.0
# 21     HOLLIDAY ELEM.   INDEPENDENT                9.0                  74.0
# 3868  GEORGE M. KOZME       CHARTER                NaN                   NaN
# 3870  TNC CAMPUS (TEX       CHARTER                NaN                   NaN
# 3871  DEPELCHIN-RICHM       CHARTER                NaN                   NaN
# 3874     HELPING HAND       CHARTER                NaN                   NaN
# 3875  UT - UNIVERSITY       CHARTER                NaN                   NaN
# 3876  SHRINERS HOSPIT       CHARTER                NaN                   NaN
# 3877      AUSTIN OAKS       CHARTER                NaN                   NaN
#
#       Meet Grade Level  Master Grade Level  total  mean
# 124                NaN                 NaN    0.0   NaN
# 125                NaN                 NaN    0.0   NaN
# 817                NaN                 NaN    0.0   NaN
# 819                NaN                 NaN    0.0   NaN
# 906                NaN                 NaN    0.0   NaN
# 907                NaN                 NaN    0.0   NaN
# 911                NaN                 NaN    0.0   NaN
# 1927               NaN                 NaN    0.0   NaN
# 3867               NaN                 NaN    0.0   NaN
# 3868               NaN                 NaN    0.0   NaN
# 3870               NaN                 NaN    0.0   NaN
# 3871               NaN                 NaN    0.0   NaN
# 3874               NaN                 NaN    0.0   NaN
# 3875               NaN                 NaN    0.0   NaN
# 3876               NaN                 NaN    0.0   NaN
# 3877               NaN                 NaN    0.0   NaN

# %%
independent5 = independent5.dropna(how='any')
independent5.isnull().any()

charter5 = charter5.dropna(how='any')
charter5.isnull().any()
# Out:
# CNAME                   False
# District Type           False
# Below Grade Level       False
# Approach Grade Level    False
# Meet Grade Level        False
# Master Grade Level      False
# total                   False
# mean                    False
# dtype: bool

# %%
stats5mean_ind_df = independent5['mean'].describe()
stats5mean_ind_df
# Out:
# count    3875.000000
# mean        2.522819
# std         0.244872
# min         1.000000
# 25%         2.383825
# 50%         2.555556
# 75%         2.700000
# max         3.000000
# Name: mean, dtype: float64

# %%
stats5mean_cht_df = charter5['mean'].describe()
stats5mean_cht_df
# Out:
# count    352.000000
# mean       2.407405
# std        0.327069
# min        1.000000
# 25%        2.251894
# 50%        2.478462
# 75%        2.644290
# max        2.956522
# Name: mean, dtype: float64

# %%
I_vector5 = []
for index, row in independent5.iterrows():
    I_vector5.append(row[7])

C_vector5 = []
for index, row in charter4.iterrows():
    C_vector5.append(row[7])

# %%
[len(I_vector5), len(C_vector5)]
# Out:
# [3875, 348]

# %%
(t, statp) = sp.stats.ttest_ind(I_vector5, C_vector5, equal_var=True)
statp5 = statp
statp5
# Out:
# 7.901938569773511e-88

# %%
#Boxplot using the I_vector and C_vector generated above.
boxplot_data = [I_vector5, C_vector5]
labels = ['Independent', 'Charter']

plt.figure(figsize=(9,6))
plt.boxplot(boxplot_data)

plt.ylim(0.5, 3.5)

plt.suptitle('Independent versus Charter School Means', ha='center', fontsize=16, fontweight='bold')
plt.title('2019 STAAR Test, Mathematics, Grade 5', ha='center', fontsize=16, fontweight='bold')
plt.xlabel('School Type', fontsize=14, fontweight='bold')
plt.ylabel('Mean Score', fontsize=14, fontweight='bold')
plt.xticks([1,2],['Independent (N=3875, Mean=2.523)', 'Charter (N=352, Mean=2.407)'], fontsize=12)
plt.text(0.6,0.6,f'P-Value={statp5}')

#Save figure
plt.savefig('../reports/BoxAllStudentsGrade5', dpi=300)
